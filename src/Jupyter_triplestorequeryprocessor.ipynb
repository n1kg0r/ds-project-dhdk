# %%
from processor import *
from QueryProcessor import QueryProcessor
from pandas import DataFrame
from sparql_dataframe import get 
from clean_str import remove_special_chars

class TriplestoreQueryProcessor(QueryProcessor):

    def __init__(self):
        super().__init__()

    def getAllCanvases(self):

        endpoint = "http://192.168.1.55:9999/blazegraph/sparql"
        query_canvases = """
        PREFIX ns1: <https://github.com/n1kg0r/ds-project-dhdk/attributes/> 
        PREFIX ns2: <http://purl.org/dc/elements/1.1/> 
        PREFIX ns3: <https://github.com/n1kg0r/ds-project-dhdk/relations/> 

        SELECT ?canvas ?id ?label
        WHERE {
            # ?canvas a <https://github.com/n1kg0r/ds-project-dhdk/classes/Canvas>;
            ns2:identifier ?id;
            ns1:label ?label.
        }
        """

        df_sparql_getAllCanvases = get(endpoint, query_canvases, True)
        return df_sparql_getAllCanvases
    

# create an instance of the TriplestoreQueryProcessor class
query_processor = TriplestoreQueryProcessor()

# call the getAllCanvases method to retrieve the canvases from the triplestore
canvas_df = query_processor.getAllCanvases()

# print the dataframe containing the canvases
print(canvas_df)
# Out:
#                                                 canvas  \
# 0    https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 1    https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 2    https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 3    https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 4    https://github.com/n1kg0r/ds-project-dhdk/Canv...
# ..                                                 ...
# 266  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 267  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 268  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 269  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 270  https://github.com/n1kg0r/ds-project-dhdk/Canv...
#
#                                                     id  \
# 0    https://dl.ficlit.unibo.it/iiif/2/28429/canvas...
# 1    https://dl.ficlit.unibo.it/iiif/2/28429/canvas...
# 2    https://dl.ficlit.unibo.it/iiif/2/28429/canvas...
# 3    https://dl.ficlit.unibo.it/iiif/2/28429/canvas...
# 4    https://dl.ficlit.unibo.it/iiif/2/28429/canvas...
# ..                                                 ...
# 266  https://dl.ficlit.unibo.it/iiif/2/28429/canvas...
# 267  https://dl.ficlit.unibo.it/iiif/2/28429/canvas...
# 268  https://dl.ficlit.unibo.it/iiif/2/28429/canvas...
# 269  https://dl.ficlit.unibo.it/iiif/2/28429/canvas...
# 270  https://dl.ficlit.unibo.it/iiif/2/28429/canvas...
#
#                                          label
# 0                 BO0451_CAM6537_0088_p.26.jpg
# 1         BO0451_CAM6537_0110_tavola verso.jpg
# 2                 BO0451_CAM6537_0090_p.28.jpg
# 3                 BO0451_CAM6537_0161_p.77.jpg
# 4                BO0451_CAM6537_0196_p.104.jpg
# ..                                         ...
# 266              BO0451_CAM6537_0224_p.128.jpg
# 267  BO0451_CAM6537_0228_foglio di guardia.jpg
# 268       BO0451_CAM6537_0117_tavola recto.jpg
# 269               BO0451_CAM6537_0174_p.86.jpg
# 270             BO0451_CAM6537_0012_p.VIII.jpg
#
# [271 rows x 3 columns]

# %%
from processor import *
from QueryProcessor import QueryProcessor
from pandas import DataFrame
from sparql_dataframe import get 
from clean_str import remove_special_chars

class TriplestoreQueryProcessor(QueryProcessor):

    def __init__(self):
        super().__init__()

    def getAllCollections(self):

        endpoint = "http://192.168.1.55:9999/blazegraph/sparql"
        query_collections = """
        PREFIX ns1: <https://github.com/n1kg0r/ds-project-dhdk/attributes/> 
        PREFIX ns2: <http://purl.org/dc/elements/1.1/> 
        PREFIX ns3: <https://github.com/n1kg0r/ds-project-dhdk/relations/> 

        SELECT ?collection ?id ?label
        WHERE {
           # ?collection a <https://github.com/n1kg0r/ds-project-dhdk/classes/Collection>;
           ns2:identifier ?id;
           ns1:label ?label .
        }
        """

        df_sparql_getAllCollections = get(endpoint, query_collections, True)
        return df_sparql_getAllCollections
    

# create an instance of the TriplestoreQueryProcessor class
query_processor = TriplestoreQueryProcessor()

# call the getAllCanvases method to retrieve the canvases from the triplestore
collection_df = query_processor.getAllCollections()

# print the dataframe containing the canvases
print(collection_df)
# Out:
#                                           collection  \
# 0  https://github.com/n1kg0r/ds-project-dhdk/Coll...
# 1  https://github.com/n1kg0r/ds-project-dhdk/Coll...
#
#                                                   id                     label
# 0   https://dl.ficlit.unibo.it/iiif/28429/collection  Works of Dante Alighieri
# 1  https://dl.ficlit.unibo.it/iiif/19428-19425/co...   Fondo Giuseppe Raimondi

# %%
from processor import *
from QueryProcessor import QueryProcessor
from pandas import DataFrame
from sparql_dataframe import get 
from clean_str import remove_special_chars

class TriplestoreQueryProcessor(QueryProcessor):

   def __init__(self):
        super().__init__()

   def getAllManifest(self):

         endpoint = "http://192.168.1.55:9999/blazegraph/sparql"
         query_manifest = """
         PREFIX ns1: <https://github.com/n1kg0r/ds-project-dhdk/attributes/> 
         PREFIX ns2: <http://purl.org/dc/elements/1.1/> 
         PREFIX ns3: <https://github.com/n1kg0r/ds-project-dhdk/relations/> 

         SELECT ?manifest ?id ?label
         WHERE {
            # ?manifest a <https://github.com/n1kg0r/ds-project-dhdk/classes/Manifest>;
            ns2:identifier ?id;
            ns1:label ?label .
         }
         """

         df_sparql_getAllManifest = get(endpoint, query_manifest, True)
         return df_sparql_getAllManifest
   
# create an instance of the TriplestoreQueryProcessor class
query_processor = TriplestoreQueryProcessor()

# call the getAllCanvases method to retrieve the canvases from the triplestore
manifest_df = query_processor.getAllManifest()

# print the dataframe containing the canvases
print(manifest_df)
# Out:
#                                             manifest  \
# 0  https://github.com/n1kg0r/ds-project-dhdk/Mani...
# 1  https://github.com/n1kg0r/ds-project-dhdk/Mani...
# 2  https://github.com/n1kg0r/ds-project-dhdk/Mani...
#
#                                                  id  \
# 0  https://dl.ficlit.unibo.it/iiif/2/28429/manifest
# 1  https://dl.ficlit.unibo.it/iiif/2/19425/manifest
# 2  https://dl.ficlit.unibo.it/iiif/2/19428/manifest
#
#                                                label
# 0                                      Il Canzoniere
# 1  Raimondi, Giuseppe. Quaderno manoscritto, "La ...
# 2  Raimondi, Giuseppe. Quaderno manoscritto, "Cas...

# %%
from processor import *
from QueryProcessor import QueryProcessor
from pandas import DataFrame
from sparql_dataframe import get 
from clean_str import remove_special_chars

class TriplestoreQueryProcessor(QueryProcessor):

    def __init__(self):
        super().__init__()
        
    def getCanvasesInCollection(self, collectionId: str):

        endpoint = "http://192.168.1.55:9999/blazegraph/sparql"
        query_canInCol = """
        PREFIX ns1: <https://github.com/n1kg0r/ds-project-dhdk/attributes/> 
        PREFIX ns2: <http://purl.org/dc/elements/1.1/> 
        PREFIX ns3: <https://github.com/n1kg0r/ds-project-dhdk/relations/> 

        SELECT ?canvas ?id ?label 
        WHERE {
            # ?collection a <https://github.com/n1kg0r/ds-project-dhdk/classes/Collection> ;
            ns2:identifier "%s" ;
            ns3:items ?manifest .
            # ?manifest a <https://github.com/n1kg0r/ds-project-dhdk/classes/Manifest> ;
            ns3:items ?canvas .
            # ?canvas a <https://github.com/n1kg0r/ds-project-dhdk/classes/Canvas> ;
            ns2:identifier ?id ;
            ns1:label ?label .
        }
        """ % collectionId

        df_sparql_getCanvasesInCollection = get(endpoint, query_canInCol, True)
        return df_sparql_getCanvasesInCollection
    
# create an instance of the TriplestoreQueryProcessor class
query_processor = TriplestoreQueryProcessor()

# call the getAllCanvases method to retrieve the canvases from the triplestore
CanvasesinCol_df = query_processor.getCanvasesInCollection("https://dl.ficlit.unibo.it/iiif/19428-19425/collection")

# print the dataframe containing the canvases
print(CanvasesinCol_df)
# Out:
#                                                canvas  \
# 0   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 1   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 2   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 3   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 4   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 5   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 6   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 7   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 8   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 9   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 10  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 11  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 12  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 13  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 14  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 15  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 16  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 17  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 18  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 19  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 20  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 21  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 22  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 23  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 24  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 25  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 26  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 27  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 28  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 29  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 30  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 31  https://github.com/n1kg0r/ds-project-dhdk/Canv...
#
#                                                    id   label
# 0   https://dl.ficlit.unibo.it/iiif/2/19425/canvas/p5     c2r
# 1   https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p6     c2v
# 2   https://dl.ficlit.unibo.it/iiif/2/19425/canvas...     c5v
# 3   https://dl.ficlit.unibo.it/iiif/2/19425/canvas...       r
# 4   https://dl.ficlit.unibo.it/iiif/2/19425/canvas...     c5r
# 5   https://dl.ficlit.unibo.it/iiif/2/19425/canvas/p3     c1r
# 6   https://dl.ficlit.unibo.it/iiif/2/19428/canvas...     c4v
# 7   https://dl.ficlit.unibo.it/iiif/2/19425/canvas/p7     c3r
# 8   https://dl.ficlit.unibo.it/iiif/2/19428/canvas...     c5v
# 9   https://dl.ficlit.unibo.it/iiif/2/19425/canvas...  colori
# 10  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p9     c4r
# 11  https://dl.ficlit.unibo.it/iiif/2/19425/canvas/p2       v
# 12  https://dl.ficlit.unibo.it/iiif/2/19425/canvas/p4     c1v
# 13  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p1       r
# 14  https://dl.ficlit.unibo.it/iiif/2/19425/canvas/p1       r
# 15  https://dl.ficlit.unibo.it/iiif/2/19428/canvas...     c5r
# 16  https://dl.ficlit.unibo.it/iiif/2/19428/canvas...   scala
# 17  https://dl.ficlit.unibo.it/iiif/2/19425/canvas/p6     c2v
# 18  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p5     c2r
# 19  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...       v
# 20  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p3     c1r
# 21  https://dl.ficlit.unibo.it/iiif/2/19428/canvas...  colori
# 22  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p2       v
# 23  https://dl.ficlit.unibo.it/iiif/2/19428/canvas...       v
# 24  https://dl.ficlit.unibo.it/iiif/2/19425/canvas/p8     c3v
# 25  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p7     c3r
# 26  https://dl.ficlit.unibo.it/iiif/2/19428/canvas...       r
# 27  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...   scala
# 28  https://dl.ficlit.unibo.it/iiif/2/19425/canvas/p9     c4r
# 29  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p4     c1v
# 30  https://dl.ficlit.unibo.it/iiif/2/19425/canvas...     c4v
# 31  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p8     c3v

# %%
from processor import *
from QueryProcessor import QueryProcessor
from pandas import DataFrame
from sparql_dataframe import get 
from clean_str import remove_special_chars

class TriplestoreQueryProcessor(QueryProcessor):

    def __init__(self):
        super().__init__()
        
    def getCanvasesInManifest(self, manifestId: str):

        endpoint = "http://192.168.1.55:9999/blazegraph/sparql"
        query_canInMan = """
        PREFIX ns1: <https://github.com/n1kg0r/ds-project-dhdk/attributes/> 
        PREFIX ns2: <http://purl.org/dc/elements/1.1/> 
        PREFIX ns3: <https://github.com/n1kg0r/ds-project-dhdk/relations/> 

        SELECT ?canvas ?id ?label
        WHERE {
            # ?manifest a <https://github.com/n1kg0r/ds-project-dhdk/classes/Manifest> ;
            ns2:identifier "%s" ;
            ns3:items ?canvas .
            # ?canvas a <https://github.com/n1kg0r/ds-project-dhdk/classes/Canvas> ;
            ns2:identifier ?id ;
            ns1:label ?label .
        }
        """ % manifestId

        df_sparql_getCanvasesInManifest = get(endpoint, query_canInMan, True)
        return df_sparql_getCanvasesInManifest
    
# create an instance of the TriplestoreQueryProcessor class
query_processor = TriplestoreQueryProcessor()

# call the getAllCanvases method to retrieve the canvases from the triplestore
CanvasesinMan_df = query_processor.getCanvasesInManifest("https://dl.ficlit.unibo.it/iiif/2/19428/manifest")

# print the dataframe containing the canvases
print(CanvasesinMan_df)
# Out:
#                                                canvas  \
# 0   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 1   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 2   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 3   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 4   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 5   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 6   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 7   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 8   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 9   https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 10  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 11  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 12  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 13  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 14  https://github.com/n1kg0r/ds-project-dhdk/Canv...
# 15  https://github.com/n1kg0r/ds-project-dhdk/Canv...
#
#                                                    id   label
# 0   https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p6     c2v
# 1   https://dl.ficlit.unibo.it/iiif/2/19428/canvas...     c4v
# 2   https://dl.ficlit.unibo.it/iiif/2/19428/canvas...     c5v
# 3   https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p9     c4r
# 4   https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p1       r
# 5   https://dl.ficlit.unibo.it/iiif/2/19428/canvas...     c5r
# 6   https://dl.ficlit.unibo.it/iiif/2/19428/canvas...   scala
# 7   https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p5     c2r
# 8   https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p3     c1r
# 9   https://dl.ficlit.unibo.it/iiif/2/19428/canvas...  colori
# 10  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p2       v
# 11  https://dl.ficlit.unibo.it/iiif/2/19428/canvas...       v
# 12  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p7     c3r
# 13  https://dl.ficlit.unibo.it/iiif/2/19428/canvas...       r
# 14  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p4     c1v
# 15  https://dl.ficlit.unibo.it/iiif/2/19428/canvas/p8     c3v

# %%
from processor import *
from QueryProcessor import QueryProcessor
from pandas import DataFrame
from sparql_dataframe import get 
from clean_str import remove_special_chars

class TriplestoreQueryProcessor(QueryProcessor):

    def __init__(self):
        super().__init__()
        

    def getManifestInCollection(self, collectionId: str):

        endpoint = "http://192.168.1.55:9999/blazegraph/sparql"
        query_manInCol = """
        PREFIX ns1: <https://github.com/n1kg0r/ds-project-dhdk/attributes/> 
        PREFIX ns2: <http://purl.org/dc/elements/1.1/> 
        PREFIX ns3: <https://github.com/n1kg0r/ds-project-dhdk/relations/> 

        SELECT ?manifest ?id ?label
        WHERE {
            # ?collection a <https://github.com/n1kg0r/ds-project-dhdk/classes/Collection> ;
            ns2:identifier "%s" ;
            ns3:items ?manifest .
            # ?manifest a <https://github.com/n1kg0r/ds-project-dhdk/classes/Manifest> ;
            ns2:identifier ?id ;
            ns1:label ?label .
        }
        """ % collectionId

        df_sparql_getManifestInCollection = get(endpoint, query_manInCol, True)
        return df_sparql_getManifestInCollection
    
# create an instance of the TriplestoreQueryProcessor class
query_processor = TriplestoreQueryProcessor()

# call the getAllCanvases method to retrieve the canvases from the triplestore
ManinColl_df = query_processor.getManifestInCollection("https://dl.ficlit.unibo.it/iiif/19428-19425/collection")

# print the dataframe containing the canvases
print(ManinColl_df)
# Out:
#                                             manifest  \
# 0  https://github.com/n1kg0r/ds-project-dhdk/Mani...
# 1  https://github.com/n1kg0r/ds-project-dhdk/Mani...
#
#                                                  id  \
# 0  https://dl.ficlit.unibo.it/iiif/2/19425/manifest
# 1  https://dl.ficlit.unibo.it/iiif/2/19428/manifest
#
#                                                label
# 0  Raimondi, Giuseppe. Quaderno manoscritto, "La ...
# 1  Raimondi, Giuseppe. Quaderno manoscritto, "Cas...

# %%
from processor import *
from QueryProcessor import QueryProcessor
from pandas import DataFrame
from sparql_dataframe import get 
from clean_str import remove_special_chars

class TriplestoreQueryProcessor(QueryProcessor):

    def __init__(self):
        super().__init__()

    def getEntitiesWithLabel(self, label: str): 
            

        endpoint = "http://192.168.1.55:9999/blazegraph/sparql"
        query_entityLabel = """
        PREFIX ns1: <https://github.com/n1kg0r/ds-project-dhdk/attributes/> 
        PREFIX ns2: <http://purl.org/dc/elements/1.1/> 
        PREFIX ns3: <https://github.com/n1kg0r/ds-project-dhdk/relations/> 

        SELECT ?entity ?type ?id
        WHERE {
            # ?entity ns1:label "%s" ;
            a ?type ;
            ns2:identifier ?id .
        }
        """ % remove_special_chars(label)

        df_sparql_getEntitiesWithLabel = get(endpoint, query_entityLabel, True)
        return df_sparql_getEntitiesWithLabel


# create an instance of the TriplestoreQueryProcessor class
query_processor = TriplestoreQueryProcessor()

# call the getAllCanvases method to retrieve the canvases from the triplestore
entity_df = query_processor.getEntitiesWithLabel('Raimondi, Giuseppe. Quaderno manoscritto, "Caserma Scalo : 1930-1968"')
# entity_dt = query_processor.getEntitiesWithLabel("Raimondi, Giuseppe. Quaderno manoscritto, \"Caserma Scalo : 1930-1968\"")
# print the dataframe containing the canvases
print(entity_df)
# print(entity_dt)
# Out:
#                                               entity  \
# 0  https://github.com/n1kg0r/ds-project-dhdk/Mani...
#
#                                                 type  \
# 0  https://github.com/n1kg0r/ds-project-dhdk/clas...
#
#                                                  id
# 0  https://dl.ficlit.unibo.it/iiif/2/19428/manifest
